png:  mismatching "local" filename (Single/val/Th├┤ng m├г v─й/crop_68_patch9.png),
#          continuing with "central" filename version
#   inflating: Single/val/Thông mã vĩ/crop_68_patch9.png
# Single/val/Thông mã vĩ/crop_96_patch1.png:  mismatching "local" filename (Single/val/Th├┤ng m├г v─й/crop_96_patch1.png),
#          continuing with "central" filename version
#   inflating: Single/val/Thông mã vĩ/crop_96_patch1.png
# Single/val/Thông mã vĩ/crop_96_patch10.png:  mismatching "local" filename (Single/val/Th├┤ng m├г v─й/crop_96_patch10.png),
#          continuing with "central" filename version
#   inflating: Single/val/Thông mã vĩ/crop_96_patch10.png
# Single/val/Thông mã vĩ/crop_96_patch11.png:  mismatching "local" filename (Single/val/Th├┤ng m├г v─й/crop_96_patch11.png),
#          continuing with "central" filename version
#   inflating: Single/val/Thông mã vĩ/crop_96_patch11.png
# Single/val/Thông mã vĩ/crop_96_patch12.png:  mismatching "local" filename (Single/val/Th├┤ng m├г v─й/crop_96_patch12.png),
#          continuing with "central" filename version
#   inflating: Single/val/Thông mã vĩ/crop_96_patch12.png
# Single/val/Thông mã vĩ/crop_96_patch13.png:  mismatching "local" filename (Single/val/Th├┤ng m├г v─й/crop_96_patch13.png),
#          continuing with "central" filename version
#   inflating: Single/val/Thông mã vĩ/crop_96_patch13.png
# Single/val/Thông mã vĩ/crop_96_patch14.png:  mismatching "local" filename (Single/val/Th├┤ng m├г v─й/crop_96_patch14.png),
#          continuing with "central" filename version
#   inflating: Single/val/Thông mã vĩ/crop_96_patch14.png
# Single/val/Thông mã vĩ/crop_96_patch15.png:  mismatching "local" filename (Single/val/Th├┤ng m├г v─й/crop_96_patch15.png),
#          continuing with "central" filename version
#   inflating: Single/val/Thông mã vĩ/crop_96_patch15.png
# Single/val/Thông mã vĩ/crop_96_patch16.png:  mismatching "local" filename (Single/val/Th├┤ng m├г v─й/crop_96_patch16.png),
#          continuing with "central" filename version
#   inflating: Single/val/Thông mã vĩ/crop_96_patch16.png
# Single/val/Thông mã vĩ/crop_96_patch17.png:  mismatching "local" filename (Single/val/Th├┤ng m├г v─й/crop_96_patch17.png),
#          continuing with "central" filename version
#   inflating: Single/val/Thông mã vĩ/crop_96_patch17.png
# Single/val/Thông mã vĩ/crop_96_patch18.png:  mismatching "local" filename (Single/val/Th├┤ng m├г v─й/crop_96_patch18.png),
#          continuing with "central" filename version
#   inflating: Single/val/Thông mã vĩ/crop_96_patch18.png
# Single/val/Thông mã vĩ/crop_96_patch2.png:  mismatching "local" filename (Single/val/Th├┤ng m├г v─й/crop_96_patch2.png),
#          continuing with "central" filename version
#   inflating: Single/val/Thông mã vĩ/crop_96_patch2.png
# Single/val/Thông mã vĩ/crop_96_patch3.png:  mismatching "local" filename (Single/val/Th├┤ng m├г v─й/crop_96_patch3.png),
#          continuing with "central" filename version
#   inflating: Single/val/Thông mã vĩ/crop_96_patch3.png
# Single/val/Thông mã vĩ/crop_96_patch4.png:  mismatching "local" filename (Single/val/Th├┤ng m├г v─й/crop_96_patch4.png),
#          continuing with "central" filename version
#   inflating: Single/val/Thông mã vĩ/crop_96_patch4.png
# Single/val/Thông mã vĩ/crop_96_patch5.png:  mismatching "local" filename (Single/val/Th├┤ng m├г v─й/crop_96_patch5.png),
#          continuing with "central" filename version
#   inflating: Single/val/Thông mã vĩ/crop_96_patch5.png
# Single/val/Thông mã vĩ/crop_96_patch6.png:  mismatching "local" filename (Single/val/Th├┤ng m├г v─й/crop_96_patch6.png),
#          continuing with "central" filename version
#   inflating: Single/val/Thông mã vĩ/crop_96_patch6.png
# Single/val/Thông mã vĩ/crop_96_patch7.png:  mismatching "local" filename (Single/val/Th├┤ng m├г v─й/crop_96_patch7.png),
#          continuing with "central" filename version
#   inflating: Single/val/Thông mã vĩ/crop_96_patch7.png
# Single/val/Thông mã vĩ/crop_96_patch8.png:  mismatching "local" filename (Single/val/Th├┤ng m├г v─й/crop_96_patch8.png),
#          continuing with "central" filename version
#   inflating: Single/val/Thông mã vĩ/crop_96_patch8.png
# Single/val/Thông mã vĩ/crop_96_patch9.png:  mismatching "local" filename (Single/val/Th├┤ng m├г v─й/crop_96_patch9.png),
#          continuing with "central" filename version
#   inflating: Single/val/Thông mã vĩ/crop_96_patch9.png
# Single/val/Vả/:  mismatching "local" filename (Single/val/Vс║г/),
#          continuing with "central" filename version
#    creating: Single/val/Vả/
# Single/val/Vả/crop_453_patch1.png:  mismatching "local" filename (Single/val/Vс║г/crop_453_patch1.png),
#          continuing with "central" filename version
#   inflating: Single/val/Vả/crop_453_patch1.png
# Single/val/Vả/crop_453_patch2.png:  mismatching "local" filename (Single/val/Vс║г/crop_453_patch2.png),
#          continuing with "central" filename version
#   inflating: Single/val/Vả/crop_453_patch2.png
# Single/val/Vả/crop_453_patch3.png:  mismatching "local" filename (Single/val/Vс║г/crop_453_patch3.png),
#          continuing with "central" filename version
#   inflating: Single/val/Vả/crop_453_patch3.png
# Single/val/Vả/crop_453_patch4.png:  mismatching "local" filename (Single/val/Vс║г/crop_453_patch4.png),
#          continuing with "central" filename version
#   inflating: Single/val/Vả/crop_453_patch4.png
# Single/val/Vả/crop_464_patch1.png:  mismatching "local" filename (Single/val/Vс║г/crop_464_patch1.png),
#          continuing with "central" filename version
#   inflating: Single/val/Vả/crop_464_patch1.png
# Single/val/Vả/crop_464_patch10.png:  mismatching "local" filename (Single/val/Vс║г/crop_464_patch10.png),
#          continuing with "central" filename version
#   inflating: Single/val/Vả/crop_464_patch10.png
# Single/val/Vả/crop_464_patch2.png:  mismatching "local" filename (Single/val/Vс║г/crop_464_patch2.png),
#          continuing with "central" filename version
#   inflating: Single/val/Vả/crop_464_patch2.png
# Single/val/Vả/crop_464_patch3.png:  mismatching "local" filename (Single/val/Vс║г/crop_464_patch3.png),
#          continuing with "central" filename version
#   inflating: Single/val/Vả/crop_464_patch3.png
# Single/val/Vả/crop_464_patch4.png:  mismatching "local" filename (Single/val/Vс║г/crop_464_patch4.png),
#          continuing with "central" filename version
#   inflating: Single/val/Vả/crop_464_patch4.png
# Single/val/Vả/crop_464_patch5.png:  mismatching "local" filename (Single/val/Vс║г/crop_464_patch5.png),
#          continuing with "central" filename version
#   inflating: Single/val/Vả/crop_464_patch5.png
# Single/val/Vả/crop_464_patch6.png:  mismatching "local" filename (Single/val/Vс║г/crop_464_patch6.png),
#          continuing with "central" filename version
#   inflating: Single/val/Vả/crop_464_patch6.png
# Single/val/Vả/crop_464_patch7.png:  mismatching "local" filename (Single/val/Vс║г/crop_464_patch7.png),
#          continuing with "central" filename version
#   inflating: Single/val/Vả/crop_464_patch7.png
# Single/val/Vả/crop_464_patch8.png:  mismatching "local" filename (Single/val/Vс║г/crop_464_patch8.png),
#          continuing with "central" filename version
#   inflating: Single/val/Vả/crop_464_patch8.png
# Single/val/Vả/crop_464_patch9.png:  mismatching "local" filename (Single/val/Vс║г/crop_464_patch9.png),
#          continuing with "central" filename version
#   inflating: Single/val/Vả/crop_464_patch9.png
# Single/val/Đa/:  mismatching "local" filename (Single/val/─Рa/),
#          continuing with "central" filename version
#    creating: Single/val/Đa/
# Single/val/Đa/crop_347_patch1.png:  mismatching "local" filename (Single/val/─Рa/crop_347_patch1.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_347_patch1.png
# Single/val/Đa/crop_347_patch2.png:  mismatching "local" filename (Single/val/─Рa/crop_347_patch2.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_347_patch2.png
# Single/val/Đa/crop_347_patch3.png:  mismatching "local" filename (Single/val/─Рa/crop_347_patch3.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_347_patch3.png
# Single/val/Đa/crop_347_patch4.png:  mismatching "local" filename (Single/val/─Рa/crop_347_patch4.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_347_patch4.png
# Single/val/Đa/crop_347_patch5.png:  mismatching "local" filename (Single/val/─Рa/crop_347_patch5.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_347_patch5.png
# Single/val/Đa/crop_347_patch6.png:  mismatching "local" filename (Single/val/─Рa/crop_347_patch6.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_347_patch6.png
# Single/val/Đa/crop_347_patch7.png:  mismatching "local" filename (Single/val/─Рa/crop_347_patch7.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_347_patch7.png
# Single/val/Đa/crop_347_patch8.png:  mismatching "local" filename (Single/val/─Рa/crop_347_patch8.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_347_patch8.png
# Single/val/Đa/crop_392_patch1.png:  mismatching "local" filename (Single/val/─Рa/crop_392_patch1.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_392_patch1.png
# Single/val/Đa/crop_392_patch10.png:  mismatching "local" filename (Single/val/─Рa/crop_392_patch10.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_392_patch10.png
# Single/val/Đa/crop_392_patch11.png:  mismatching "local" filename (Single/val/─Рa/crop_392_patch11.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_392_patch11.png
# Single/val/Đa/crop_392_patch12.png:  mismatching "local" filename (Single/val/─Рa/crop_392_patch12.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_392_patch12.png
# Single/val/Đa/crop_392_patch13.png:  mismatching "local" filename (Single/val/─Рa/crop_392_patch13.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_392_patch13.png
# Single/val/Đa/crop_392_patch14.png:  mismatching "local" filename (Single/val/─Рa/crop_392_patch14.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_392_patch14.png
# Single/val/Đa/crop_392_patch15.png:  mismatching "local" filename (Single/val/─Рa/crop_392_patch15.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_392_patch15.png
# Single/val/Đa/crop_392_patch16.png:  mismatching "local" filename (Single/val/─Рa/crop_392_patch16.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_392_patch16.png
# Single/val/Đa/crop_392_patch2.png:  mismatching "local" filename (Single/val/─Рa/crop_392_patch2.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_392_patch2.png
# Single/val/Đa/crop_392_patch3.png:  mismatching "local" filename (Single/val/─Рa/crop_392_patch3.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_392_patch3.png
# Single/val/Đa/crop_392_patch4.png:  mismatching "local" filename (Single/val/─Рa/crop_392_patch4.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_392_patch4.png
# Single/val/Đa/crop_392_patch5.png:  mismatching "local" filename (Single/val/─Рa/crop_392_patch5.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_392_patch5.png
# Single/val/Đa/crop_392_patch6.png:  mismatching "local" filename (Single/val/─Рa/crop_392_patch6.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_392_patch6.png
# Single/val/Đa/crop_392_patch7.png:  mismatching "local" filename (Single/val/─Рa/crop_392_patch7.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_392_patch7.png
# Single/val/Đa/crop_392_patch8.png:  mismatching "local" filename (Single/val/─Рa/crop_392_patch8.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_392_patch8.png
# Single/val/Đa/crop_392_patch9.png:  mismatching "local" filename (Single/val/─Рa/crop_392_patch9.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_392_patch9.png
# Single/val/Đa/crop_445_patch1.png:  mismatching "local" filename (Single/val/─Рa/crop_445_patch1.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_445_patch1.png
# Single/val/Đa/crop_445_patch2.png:  mismatching "local" filename (Single/val/─Рa/crop_445_patch2.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_445_patch2.png
# Single/val/Đa/crop_445_patch3.png:  mismatching "local" filename (Single/val/─Рa/crop_445_patch3.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_445_patch3.png
# Single/val/Đa/crop_445_patch4.png:  mismatching "local" filename (Single/val/─Рa/crop_445_patch4.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_445_patch4.png
# Single/val/Đa/crop_445_patch5.png:  mismatching "local" filename (Single/val/─Рa/crop_445_patch5.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_445_patch5.png
# Single/val/Đa/crop_445_patch6.png:  mismatching "local" filename (Single/val/─Рa/crop_445_patch6.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_445_patch6.png
# Single/val/Đa/crop_445_patch7.png:  mismatching "local" filename (Single/val/─Рa/crop_445_patch7.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_445_patch7.png
# Single/val/Đa/crop_445_patch8.png:  mismatching "local" filename (Single/val/─Рa/crop_445_patch8.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_445_patch8.png
# Single/val/Đa/crop_454_patch1.png:  mismatching "local" filename (Single/val/─Рa/crop_454_patch1.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_454_patch1.png
# Single/val/Đa/crop_454_patch2.png:  mismatching "local" filename (Single/val/─Рa/crop_454_patch2.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_454_patch2.png
# Single/val/Đa/crop_454_patch3.png:  mismatching "local" filename (Single/val/─Рa/crop_454_patch3.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_454_patch3.png
# Single/val/Đa/crop_454_patch4.png:  mismatching "local" filename (Single/val/─Рa/crop_454_patch4.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_454_patch4.png
# Single/val/Đa/crop_454_patch5.png:  mismatching "local" filename (Single/val/─Рa/crop_454_patch5.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_454_patch5.png
# Single/val/Đa/crop_454_patch6.png:  mismatching "local" filename (Single/val/─Рa/crop_454_patch6.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_454_patch6.png
# Single/val/Đa/crop_454_patch7.png:  mismatching "local" filename (Single/val/─Рa/crop_454_patch7.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_454_patch7.png
# Single/val/Đa/crop_454_patch8.png:  mismatching "local" filename (Single/val/─Рa/crop_454_patch8.png),
#          continuing with "central" filename version
#   inflating: Single/val/Đa/crop_454_patch8.png

# %%
# !rm -rf "/content/Single/test/Bời Lời"
# !rm -rf "/content/Single/test/Lim xanh"
# !rm -rf "/content/Single/test/Sếu"
# !rm -rf "/content/Single/test/Lòng Mang"
# !rm -rf "/content/Single/test/Chẹo"
# !rm -rf "/content/Single/test/Mé Cò Ke"
# !rm -rf "/content/Single/test/Dẻ cau"
# !rm -rf "/content/Single/test/Nanh Chuột"
# !rm -rf "/content/Single/test/Thôi Ba"
# !rm -rf "/content/Single/test/Bời Lời Lá Tròn"
# !rm -rf "/content/Single/test/Sồi Xanh"
# !rm -rf "/content/Single/test/Lim Xẹt"

# !rm -rf "/content/Single/train/Bời Lời"
# !rm -rf "/content/Single/train/Lim xanh"
# !rm -rf "/content/Single/train/Sếu"
# !rm -rf "/content/Single/train/Lòng Mang"
# !rm -rf "/content/Single/train/Chẹo"
# !rm -rf "/content/Single/train/Mé Cò Ke"
# !rm -rf "/content/Single/train/Dẻ cau"
# !rm -rf "/content/Single/train/Nanh Chuột"
# !rm -rf "/content/Single/train/Thôi Ba"
# !rm -rf "/content/Single/train/Bời Lời Lá Tròn"
# !rm -rf "/content/Single/train/Sồi Xanh"
# !rm -rf "/content/Single/train/Lim Xẹt"

# !rm -rf "/content/Single/val/Bời Lời"
# !rm -rf "/content/Single/val/Lim xanh"
# !rm -rf "/content/Single/val/Sếu"
# !rm -rf "/content/Single/val/Lòng Mang"
# !rm -rf "/content/Single/val/Chẹo"
# !rm -rf "/content/Single/val/Mé Cò Ke"
# !rm -rf "/content/Single/val/Dẻ cau"
# !rm -rf "/content/Single/val/Nanh Chuột"
# !rm -rf "/content/Single/val/Thôi Ba"
# !rm -rf "/content/Single/val/Bời Lời Lá Tròn"
# !rm -rf "/content/Single/val/Sồi Xanh"
# !rm -rf "/content/Single/val/Lim Xẹt"

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class FocalLoss(nn.Module):
    """Focal Loss for handling class imbalance"""
    def __init__(self, alpha=1, gamma=2, reduction='mean'):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.reduction = reduction

    def forward(self, inputs, targets):
        ce_loss = nn.CrossEntropyLoss(reduction='none')(inputs, targets)
        pt = torch.exp(-ce_loss)
        focal_loss = self.alpha * (1 - pt) ** self.gamma * ce_loss

        if self.reduction == 'mean':
            return focal_loss.mean()
        elif self.reduction == 'sum':
            return focal_loss.sum()
        else:
            return focal_loss

# --- Primary Losses ---

class OnlineTripletLoss(nn.Module):
    """Triplet Loss with Batch Hard mining"""
    def __init__(self, margin=0.3):
        super(OnlineTripletLoss, self).__init__()
        self.margin = margin

    def forward(self, features, targets):
        # Pairwise distances
        n = features.size(0)
        dist = torch.pow(features, 2).sum(dim=1, keepdim=True).expand(n, n)
        dist = dist + dist.t()
        dist.addmm_(features, features.t(), beta=1, alpha=-2)
        dist = dist.clamp(min=1e-12).sqrt()  # for numerical stability

        # Masks
        mask_anchor_positive = targets.expand(n, n).eq(targets.expand(n, n).t())
        mask_anchor_negative = targets.expand(n, n).ne(targets.expand(n, n).t())

        # Batch Hard Mining
        # Max distance for positives (hardest positive)
        hardest_positive_dist = (dist * mask_anchor_positive.float()).max(dim=1)[0]

        # Min distance for negatives (hardest negative)
        # Add max_dist to invalid positions before taking min
        max_dist = dist.max().item()
        hardest_negative_dist = (dist + max_dist * (~mask_anchor_negative).float()).min(dim=1)[0]

        triplet_loss = F.relu(hardest_positive_dist - hardest_negative_dist + self.margin)
        return triplet_loss.mean()

class CenterLoss(nn.Module):
    """Center Loss for reducing intra-class variance"""
    def __init__(self, num_classes, feat_dim, use_gpu=True):
        super(CenterLoss, self).__init__()
        self.num_classes = num_classes
        self.feat_dim = feat_dim
        self.use_gpu = use_gpu

        if self.use_gpu:
            self.centers = nn.Parameter(torch.randn(self.num_classes, self.feat_dim).cuda())
        else:
            self.centers = nn.Parameter(torch.randn(self.num_classes, self.feat_dim))

    def forward(self, features, targets):
        batch_size = features.size(0)
        distmat = torch.pow(features, 2).sum(dim=1, keepdim=True).expand(batch_size, self.num_classes) + \
                  torch.pow(self.centers, 2).sum(dim=1, keepdim=True).expand(self.num_classes, batch_size).t()
        distmat.addmm_(features, self.centers.t(), beta=1, alpha=-2)

        classes = torch.arange(self.num_classes).long()
        if self.use_gpu: classes = classes.cuda()

        labels = targets.unsqueeze(1).expand(batch_size, self.num_classes)
        mask = labels.eq(classes.expand(batch_size, self.num_classes))

        dist = distmat * mask.float()
        loss = dist.clamp(min=1e-12, max=1e+12).sum() / batch_size
        return loss

# --- Secondary Losses ---

class EntropyLoss(nn.Module):
    """Minimum Entropy Regularization"""
    def __init__(self):
        super(EntropyLoss, self).__init__()

    def forward(self, logits):
        p = F.softmax(logits, dim=1)
        log_p = F.log_softmax(logits, dim=1)
        loss = -torch.sum(p * log_p, dim=1).mean()
        return loss

class PNormLoss(nn.Module):
    """P-Norm Regularization on Features"""
    def __init__(self, p=2):
        super(PNormLoss, self).__init__()
        self.p = p

    def forward(self, features):
        return torch.norm(features, p=self.p, dim=1).mean()

class CORALLoss(nn.Module):
    """Correlation Alignment Loss (Placeholder for single domain)"""
    def __init__(self):
        super(CORALLoss, self).__init__()

    def forward(self, features):
        # For single batch/domain, usually used to decorrelate or match a prior.
        # Here we just return 0 if no target domain provided, or covariance norm.
        # Simplified: minimize covariance norm (decorrelation)
        n = features.size(0)
        d = features.size(1)
        mean = features.mean(dim=0, keepdim=True)
        features_centered = features - mean
        cov = features_centered.t().mm(features_centered) / (n - 1)
        return torch.norm(cov, p='fro')

class CombinedLoss(nn.Module):
    """Combined Loss: L_total = L_class + lambda1 * L_primary + lambda2 * L_secondary"""
    def __init__(self, base_criterion, primary_criteria=None, secondary_criteria=None,
                 lambda_primary=0.01, lambda_secondary=0.01):
        super(CombinedLoss, self).__init__()
        self.base_criterion = base_criterion
        self.primary_criteria = primary_criteria if primary_criteria else []
        self.secondary_criteria = secondary_criteria if secondary_criteria else []
        self.lambda_primary = lambda_primary
        self.lambda_secondary = lambda_secondary

    def forward(self, logits, labels, features):
        # Base Classification Loss
        loss = self.base_criterion(logits, labels)

        # Primary Losses (require features and labels)
        if self.primary_criteria:
            p_loss = 0
            for criterion in self.primary_criteria:
                p_loss += criterion(features, labels)
            loss += self.lambda_primary * p_loss

        # Secondary Losses (varied inputs)
        if self.secondary_criteria:
            s_loss = 0
            for criterion in self.secondary_criteria:
                if isinstance(criterion, EntropyLoss):
                    s_loss += criterion(logits)
                elif isinstance(criterion, (PNormLoss, CORALLoss)):
                    s_loss += criterion(features)
                # Add other cases if needed
            loss += self.lambda_secondary * s_loss

        return loss

# %%
class EarlyStopping:
    """Early stopping callback"""
    def __init__(self, patience=7, min_delta=0, mode='max'):
        self.patience = patience
        self.min_delta = min_delta
        self.mode = mode
        self.counter = 0
        self.best_score = None
        self.early_stop = False

    def __call__(self, score):
        if self.best_score is None:
            self.best_score = score
        elif self.mode == 'max':
            if score < self.best_score + self.min_delta:
                self.counter += 1
                if self.counter >= self.patience:
                    self.early_stop = True
            else:
                self.best_score = score
                self.counter = 0
        else:  # mode == 'min'
            if score > self.best_score - self.min_delta:
                self.counter += 1
                if self.counter >= self.patience:
                    self.early_stop = True
            else:
                self.best_score = score
                self.counter = 0

        return self.early_stop

class ModelCheckpoint:
    """Model checkpoint callback"""
    def __init__(self, filepath, monitor='val_loss', mode='min', save_best_only=True):
        self.filepath = filepath
        self.monitor = monitor
        self.mode = mode
        self.save_best_only = save_best_only
        self.best_score = None

    def __call__(self, model, optimizer, epoch, metrics):
        score = metrics.get(self.monitor)

        if not self.save_best_only:
            self._save_model(model, optimizer, epoch, metrics)
            return False

        if self.best_score is None:
            self.best_score = score
            self._save_model(model, optimizer, epoch, metrics)
            return True

        improved = False
        if self.mode == 'max' and score > self.best_score:
            self.best_score = score
            self._save_model(model, optimizer, epoch, metrics)
            improved = True
        elif self.mode == 'min' and score < self.best_score:
            self.best_score = score
            self._save_model(model, optimizer, epoch, metrics)
            improved = True

        return improved

    def _save_model(self, model, optimizer, epoch, metrics):
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'metrics': metrics
        }, self.filepath)

class ReduceLROnPlateau:
    """Reduce learning rate when a metric has stopped improving"""
    def __init__(self, optimizer, monitor='val_loss', mode='min', factor=0.5,
                 patience=5, min_lr=1e-6, verbose=1):
        self.optimizer = optimizer
        self.monitor = monitor
        self.mode = mode
        self.factor = factor
        self.patience = patience
        self.min_lr = min_lr
        self.verbose = verbose

        self.best_score = None
        self.counter = 0
        self.current_lr = optimizer.param_groups[0]['lr']

    def __call__(self, metrics):
        score = metrics.get(self.monitor)

        if self.best_score is None:
            self.best_score = score
            return

        improved = False
        if self.mode == 'min':
            improved = score < self.best_score
        else:  # mode == 'max'
            improved = score > self.best_score

        if improved:
            self.best_score = score
            self.counter = 0
        else:
            self.counter += 1

            if self.counter >= self.patience:
                old_lr = self.current_lr
                new_lr = max(old_lr * self.factor, self.min_lr)

                if new_lr < old_lr:
                    for param_group in self.optimizer.param_groups:
                        param_group['lr'] = new_lr
                    self.current_lr = new_lr
                    self.counter = 0

                    if self.verbose:
                        print(f"\n📉 ReduceLROnPlateau: reducing learning rate from {old_lr:.6f} to {new_lr:.6f}")

class LearningRateSchedulerCallback:
    """Learning rate scheduler callback with warmup"""
    def __init__(self, optimizer, warmup_epochs=5, min_lr=1e-6):
        self.optimizer = optimizer
        self.warmup_epochs = warmup_epochs
        self.min_lr = min_lr
        self.initial_lr = optimizer.param_groups[0]['lr']

    def on_epoch_end(self, epoch, scheduler):
        if epoch < self.warmup_epochs:
            # Warmup phase
            lr = self.initial_lr * (epoch + 1) / self.warmup_epochs
            for param_group in self.optimizer.param_groups:
                param_group['lr'] = lr
        else:
            # Normal scheduling
            scheduler.step()

# %%
class PlantModel(nn.Module):
    """Wrapper to return both features and logits"""
    def __init__(self, model_name, num_classes, pretrained=True):
        super(PlantModel, self).__init__()
        # Create model with num_classes=0 to get pooling output (features)
        self.backbone = timm.create_model(model_name, pretrained=pretrained, num_classes=0)
        self.num_features = self.backbone.num_features
        self.classifier = nn.Linear(self.num_features, num_classes)

    def forward(self, x):
        features = self.backbone(x)
        logits = self.classifier(features)
        return logits, features

class ModelTrainer:
    def __init__(self, train_dir, val_dir, test_dir, model_name='densenet201',
                 img_size=224, batch_size=64, lr=1e-4, epochs=50,
                 use_focal_loss=False, focal_alpha=1, focal_gamma=2,
                 primary_loss=None, secondary_loss=None,
                 lambda_primary=0.01, lambda_secondary=0.01,
                 device=None):

        self.train_dir = train_dir
        self.val_dir = val_dir
        self.test_dir = test_dir
        self.model_name = model_name
        self.img_size = img_size
        self.batch_size = batch_size
        self.lr = lr
        self.epochs = epochs
        self.use_focal_loss = use_focal_loss

        # New Loss Params
        self.primary_loss_name = primary_loss
        self.secondary_loss_name = secondary_loss
        self.lambda_primary = lambda_primary
        self.lambda_secondary = lambda_secondary

        self.device = device if device else torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        # Training history
        self.train_losses = []
        self.val_losses = []
        self.train_accs = []
        self.val_accs = []
        self.val_precisions = []
        self.val_recalls = []
        self.val_f1s = []
        self.learning_rates = []

        # Callbacks
        self.callbacks = []

        self._setup_data()
        self._setup_model(focal_alpha, focal_gamma)
        self._setup_optimizer()

    def _setup_data(self):
        """Setup DataLoader"""
        train_transform = transforms.Compose([
            transforms.Resize((self.img_size, self.img_size)),
            transforms.RandomHorizontalFlip(p=0.5),
            transforms.RandomRotation(degrees=15),
            transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.05),
            transforms.RandomAdjustSharpness(sharpness_factor=2, p=0.3),
            transforms.GaussianBlur(kernel_size=3, sigma=(0.1, 1.0)),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        ])

        test_transform = transforms.Compose([
            transforms.Resize((self.img_size, self.img_size)),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        ])

        self.train_dataset = datasets.ImageFolder(self.train_dir, transform=train_transform)
        self.val_dataset = datasets.ImageFolder(self.val_dir, transform=test_transform)
        self.test_dataset = datasets.ImageFolder(self.test_dir, transform=test_transform)

        self.train_loader = DataLoader(self.train_dataset, batch_size=self.batch_size, shuffle=True, num_workers=4, pin_memory=True)
        self.val_loader = DataLoader(self.val_dataset, batch_size=self.batch_size, shuffle=False, num_workers=4, pin_memory=True)
        self.test_loader = DataLoader(self.test_dataset, batch_size=self.batch_size, shuffle=False, num_workers=4, pin_memory=True)

        self.num_classes = len(self.train_dataset.classes)
        self.class_names = self.train_dataset.classes
        print(f"Number of classes: {self.num_classes}")

    def _setup_model(self, focal_alpha, focal_gamma):
        """Setup model and combined loss function"""
        # Use Wrapper to get features
        self.model = PlantModel(self.model_name, self.num_classes)
        self.model = self.model.to(self.device)

        # Base Loss
        if self.use_focal_loss:
            base_loss = FocalLoss(alpha=focal_alpha, gamma=focal_gamma)
            print(f"Using Focal Loss (alpha={focal_alpha}, gamma={focal_gamma})")
        else:
            base_loss = nn.CrossEntropyLoss()
            print("Using CrossEntropy Loss")

        # Primary Losses
        primary_criteria = []
        if self.primary_loss_name:
            if 'triplet' in self.primary_loss_name.lower():
                print("Adding Triplet Loss")
                primary_criteria.append(OnlineTripletLoss())
            if 'center' in self.primary_loss_name.lower():
                print("Adding Center Loss")
                # CenterLoss requires feature dimension
                feat_dim = self.model.num_features
                primary_criteria.append(CenterLoss(self.num_classes, feat_dim, use_gpu=(self.device.type=='cuda')))

        # Secondary Losses
        secondary_criteria = []
        if self.secondary_loss_name:
            names = self.secondary_loss_name.lower()
            if 'entropy' in names:
                print("Adding Entropy Loss")
                secondary_criteria.append(EntropyLoss())
            if 'pnorm' in names:
                print("Adding P-Norm Loss")
                secondary_criteria.append(PNormLoss())
            if 'coral' in names:
                print("Adding CORAL Loss")
                secondary_criteria.append(CORALLoss())

        # Combined Loss
        self.criterion = CombinedLoss(
            base_loss,
            primary_criteria,
            secondary_criteria,
            self.lambda_primary,
            self.lambda_secondary
        )

        print(f"Model: {self.model_name}")
        print(f"Device: {self.device}")

    def _setup_optimizer(self):
        """Setup optimizer and scheduler"""
        # Collect parameters: model params + loss params (e.g., centers)
        params = list(self.model.parameters())

        # Check if any primary criteria is CenterLoss and add its parameters
        for criterion in self.criterion.primary_criteria:
            if isinstance(criterion, CenterLoss):
                print("Adding CenterLoss centers to optimizer")
                params.append(criterion.centers)

        self.optimizer = optim.AdamW(params, lr=self.lr, weight_decay=0.05)
        self.scheduler = optim.lr_scheduler.CosineAnnealingLR(self.optimizer, T_max=self.epochs)

    def add_callback(self, callback):
        self.callbacks.append(callback)

    def train_epoch(self):
        self.model.train()
        running_loss = 0.0
        correct = 0
        total = 0

        pbar = tqdm(self.train_loader, desc="Training")
        for images, labels in pbar:
            images, labels = images.to(self.device), labels.to(self.device)

            self.optimizer.zero_grad()
            # Model returns (logits, features)
            logits, features = self.model(images)

            # Criterion expects (logits, labels, features)
            loss = self.criterion(logits, labels, features)

            loss.backward()
            self.optimizer.step()

            running_loss += loss.item()
            _, predicted = torch.max(logits.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

            pbar.set_postfix({'Loss': f'{loss.item():.4f}', 'Acc': f'{100.*correct/total:.2f}%'})

        return running_loss / len(self.train_loader), 100. * correct / total

    def validate_epoch(self, data_loader, desc="Validation"):
        self.model.eval()
        running_loss = 0.0
        correct = 0
        total = 0
        all_predicted = []
        all_labels = []

        with torch.no_grad():
            pbar = tqdm(data_loader, desc=desc)
            for images, labels in pbar:
                images, labels = images.to(self.device), labels.to(self.device)

                logits, features = self.model(images)
                loss = self.criterion(logits, labels, features)

                running_loss += loss.item()
                _, predicted = torch.max(logits, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

                all_predicted.extend(predicted.cpu().numpy())
                all_labels.extend(labels.cpu().numpy())

                pbar.set_postfix({'Loss': f'{loss.item():.4f}', 'Acc': f'{100.*correct/total:.2f}%'})

        epoch_loss = running_loss / len(data_loader)
        epoch_acc = 100. * correct / total
        precision, recall, f1, _ = precision_recall_fscore_support(all_labels, all_predicted, average='macro', zero_division=0)

        return epoch_loss, epoch_acc, precision*100, recall*100, f1*100, all_predicted, all_labels

    def train(self):
        print("Start training..."); print("="*50)
        for epoch in range(self.epochs):
            start_time = time.time()
            train_loss, train_acc = self.train_epoch()
            val_loss, val_acc, val_precision, val_recall, val_f1, _, _ = self.validate_epoch(self.val_loader, "Validation")
            current_lr = self.optimizer.param_groups[0]['lr']

            self.train_losses.append(train_loss); self.val_losses.append(val_loss)
            self.train_accs.append(train_acc); self.val_accs.append(val_acc)
            self.val_precisions.append(val_precision); self.val_recalls.append(val_recall)
            self.val_f1s.append(val_f1); self.learning_rates.append(current_lr)

            metrics = {'train_loss': train_loss, 'train_acc': train_acc, 'val_loss': val_loss, 'val_acc': val_acc,
                       'val_precision': val_precision, 'val_recall': val_recall, 'val_f1': val_f1}

            should_stop = False
            for callback in self.callbacks:
                if isinstance(callback, EarlyStopping):
                    if callback(val_loss):
                        print(f"🛑 Early stopping triggered at epoch {epoch+1}"); should_stop = True; break
                elif isinstance(callback, ModelCheckpoint):
                    if callback(self.model, self.optimizer, epoch, metrics):
                        print(f"💾 Saved best model at epoch {epoch+1}")
                elif isinstance(callback, ReduceLROnPlateau):
                    callback(metrics)
                elif isinstance(callback, LearningRateSchedulerCallback):
                    callback.on_epoch_end(epoch, self.scheduler)

            if not any(isinstance(cb, LearningRateSchedulerCallback) for cb in self.callbacks):
                self.scheduler.step()

            print(f"Epoch {epoch+1}/{self.epochs}")
            print(f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%")
            print(f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.2f}%")
            print(f"Val Precision: {val_precision:.2f}%, Val Recall: {val_recall:.2f}%, Val F1: {val_f1:.2f}%")
            print(f"LR: {current_lr:.6f}, Time: {time.time()-start_time:.2f}s")
            print("-" * 70)
            if should_stop: break

        return self._get_best_checkpoint_path()

    def _get_best_checkpoint_path(self):
        for callback in self.callbacks:
            if isinstance(callback, ModelCheckpoint): return callback.filepath
        return None

    def evaluate_on_test(self, model_path=None):
        if model_path and os.path.exists(model_path):
            print(f"Loading model from {model_path}")
            checkpoint = torch.load(model_path)
            self.model.load_state_dict(checkpoint['model_state_dict'])
        print("\n" + "="*70 + "\n🧪 EVALUATING ON TEST SET\n" + "="*70)
        test_loss, test_acc, test_precision, test_recall, test_f1, test_predicted, test_labels = self.validate_epoch(self.test_loader, "Testing")
        precision_per_class, recall_per_class, f1_per_class, support = precision_recall_fscore_support(test_labels, test_predicted, average=None, zero_division=0)
        print("\n🎯 DETAILED TEST RESULTS\n" + "="*70)
        print(f"Overall Accuracy: {test_acc:.2f}%"); print(f"Overall Precision (Macro): {test_precision:.2f}%")
        print(f"Overall Recall (Macro): {test_recall:.2f}%"); print(f"Overall F1-Score (Macro): {test_f1:.2f}%")
        print("="*70)
        print("\n📊 PER-CLASS METRICS:"); print("-"*70)
        print(f"{'Class':<20} {'Precision':<12} {'Recall':<12} {'F1-Score':<12} {'Support':<10}"); print("-"*70)
        for i, class_name in enumerate(self.class_names):
            print(f"{class_name:<20} {precision_per_class[i]*100:<11.2f}% {recall_per_class[i]*100:<11.2f}% {f1_per_class[i]*100:<11.2f}% {support[i]:<10}")
        print("-"*70)
        print("\n📈 CLASSIFICATION REPORT:")
        print(classification_report(test_labels, test_predicted, target_names=self.class_names, digits=4))
        metrics_summary = {'test_accuracy': float(test_acc), 'test_precision': float(test_precision),
                           'test_recall': float(test_recall), 'test_f1_score': float(test_f1),
                           'per_class_metrics': {class_name: {'precision': float(precision_per_class[i]*100),
                                                              'recall': float(recall_per_class[i]*100),
                                                              'f1_score': float(f1_per_class[i]*100),
                                                              'support': int(support[i])} for i, class_name in enumerate(self.class_names)}}
        with open('test_metrics.json', 'w') as f: json.dump(metrics_summary, f, indent=4)
        print("\n💾 Test metrics saved to test_metrics.json")
        return test_predicted, test_labels, metrics_summary

# %%
def plot_training_history(trainer_or_history, save_path='training_history.png'):
    """Plot training history

    Args:
        trainer_or_history: Can be either a trainer object or path to history JSON file
        save_path: Path to save the plot
    """
    # If it's a string (file path), load the history
    if isinstance(trainer_or_history, str):
        with open(trainer_or_history, 'r') as f:
            history = json.load(f)
        train_losses = history['train_losses']
        val_losses = history['val_losses']
        train_accs = history['train_accs']
        val_accs = history['val_accs']
        val_precisions = history['val_precisions']
        val_recalls = history['val_recalls']
        val_f1s = history['val_f1s']
        learning_rates = history['learning_rates']
    else:
        # If it's a trainer object
        train_losses = trainer_or_history.train_losses
        val_losses = trainer_or_history.val_losses
        train_accs = trainer_or_history.train_accs
        val_accs = trainer_or_history.val_accs
        val_precisions = trainer_or_history.val_precisions
        val_recalls = trainer_or_history.val_recalls
        val_f1s = trainer_or_history.val_f1s
        learning_rates = trainer_or_history.learning_rates

    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(20, 12))

    # Loss plot
    ax1.plot(train_losses, label='Train Loss', color='blue', linewidth=2)
    ax1.plot(val_losses, label='Val Loss', color='red', linewidth=2)
    ax1.set_title('Training and Validation Loss', fontsize=14, fontweight='bold')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Loss')
    ax1.legend()
    ax1.grid(True, alpha=0.3)

    # Accuracy plot
    ax2.plot(train_accs, label='Train Acc', color='blue', linewidth=2)
    ax2.plot(val_accs, label='Val Acc', color='red', linewidth=2)
    ax2.set_title('Training and Validation Accuracy', fontsize=14, fontweight='bold')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Accuracy (%)')
    ax2.legend()
    ax2.grid(True, alpha=0.3)

    # Precision and Recall plot
    ax3.plot(val_precisions, label='Val Precision', color='green', linewidth=2)
    ax3.plot(val_recalls, label='Val Recall', color='orange', linewidth=2)
    ax3.set_title('Validation Precision and Recall', fontsize=14, fontweight='bold')
    ax3.set_xlabel('Epoch')
    ax3.set_ylabel('Percentage (%)')
    ax3.legend()
    ax3.grid(True, alpha=0.3)

    # F1-Score and Learning Rate plot
    ax4_twin = ax4.twinx()
    ax4.plot(val_f1s, label='Val F1-Score', color='purple', linewidth=2)
    ax4_twin.plot(learning_rates, label='Learning Rate', color='brown',
                  linewidth=2, linestyle='--')
    ax4.set_title('Validation F1-Score and Learning Rate', fontsize=14, fontweight='bold')
    ax4.set_xlabel('Epoch')
    ax4.set_ylabel('F1-Score (%)', color='purple')
    ax4_twin.set_ylabel('Learning Rate', color='brown')
    ax4.legend(loc='upper left')
    ax4_twin.legend(loc='upper right')
    ax4.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    print(f"📊 Training history plot saved to {save_path}")
    plt.show()


def plot_confusion_matrix(test_labels, test_predicted, class_names,
                         save_path='confusion_matrix.png',
                         scientific_names=None, normalize_per_row=True):
    """Plot confusion matrix with smart color normalization

    Args:
        test_labels: True labels
        test_predicted: Predicted labels
        class_names: Original class names (folder names)
        save_path: Path to save the plot
        scientific_names: List of scientific names to display (if None, use class_names)
        normalize_per_row: If True, normalize colors by row percentage (better for imbalanced data)
    """
    cm = confusion_matrix(test_labels, test_predicted)

    # Use scientific names if provided, otherwise use original class names
    display_names = scientific_names if scientific_names is not None else class_names

    # Create figure
    fig, ax = plt.subplots(figsize=(16, 14))

    if normalize_per_row:
        # Calculate percentage for each row (for coloring only)
        cm_percent = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm_percent = np.nan_to_num(cm_percent)  # Handle division by zero

        # Use percentage values for coloring (0-1 scale)
        # But annotate with actual counts
        sns.heatmap(cm_percent,
                    annot=cm,  # Show counts
                    fmt='d',   # Integer format
                    cmap='Blues',
                    xticklabels=display_names,
                    yticklabels=display_names,
                    cbar_kws={'label': 'Percentage (color scale)'},
                    vmin=0,
                    vmax=1,
                    ax=ax)

        title = 'Confusion Matrix (colors = row percentages, values = counts)'
    else:
        # Standard confusion matrix without normalization
        sns.heatmap(cm,
                    annot=True,
                    fmt='d',
                    cmap='Blues',
                    xticklabels=display_names,
                    yticklabels=display_names,
                    cbar_kws={'label': 'Count'},
                    ax=ax)

        title = 'Confusion Matrix (Counts)'

    plt.title(title, fontsize=16, fontweight='bold', pad=20)
    plt.ylabel('True Label', fontsize=12)
    plt.xlabel('Predicted Label', fontsize=12)
    plt.xticks(rotation=45, ha='right', fontsize=9)
    plt.yticks(rotation=0, fontsize=9)
    plt.tight_layout()
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    print(f"📊 Confusion matrix saved to {save_path}")
    plt.show()

# %%
# Constants
TRAIN_DIR = "/content/Single/train"
VAL_DIR = "/content/Single/val"
TEST_DIR = "/content/Single/test"

SCIENTIFIC_NAMES = [
    'Lagerstroemia speciosa',      # Bằng lăng
    # 'Litsea glutinosa',             # Bời Lời Lá Tròn
    # 'Quercus platycalyx',           # Dẻ Cau
    'Aphanamixis grandiflora',      # Gội
    'Aphanamixis grandifolia',      # Gội trắng
    'Acacia auriculiformis (deciduous)',        # Keo Lá Tràm
    'Acacia auriculiformis',        # Keo Lá Tràm (rụng lá)
    # 'Peltophorum pterocarpum',      # Lim Xẹt
    'Chukrasia tabularis',          # Lát Hoa
    'Grewia paniculata',            # Mé Cò Ke
    # 'Cryptocarya lenticellata',     # Nanh Chuột
    'Delonix regia',                # Phượng vĩ
    'Cinnamomum parthenoxylon',     # Re hương
    'Dracontomelon dao',            # Sấu
    'Castanopsis cerebrina',        # Sồi Phảng
    # 'Lithocarpus pseudosundaicus',  # Sồi Xanh
    'Alstonia scholaris',           # Sữa
    # 'Alangium chinense',            # Thôi Ba
    'Pinus massoniana',             # Thông mã vĩ
    'Ficus auriculata',             # Vả
    'Ficus benghalensis'            # Đa
]

DEFAULT_CONFIG = {
    'model_name': 'densenet201',
    'img_size': 224,
    'batch_size': 64,
    'lr': 1e-3,
    'epochs': 50,
    'use_focal_loss': True,
    'focal_alpha': 1.0,
    'focal_gamma': 2.0,
    # New loss components
    'primary_loss': 'center',   # Options: 'triplet', 'center', 'triplet+center' or None
    'secondary_loss': 'coral', # Options: 'entropy', 'pnorm', 'coral', 'mmd' or None
    'lambda_primary': 0.01,
    'lambda_secondary': 0.01
}

def run_training(config=DEFAULT_CONFIG):
    """Run training process"""
    for path, name in [(TRAIN_DIR, "train"), (VAL_DIR, "validation"), (TEST_DIR, "test")]:
        if not os.path.exists(path):
            print(f"❌ Cannot find {name} directory: {path}")
            return None

    print("🚀 Starting Training Process with Advanced Losses...")

    trainer = ModelTrainer(
        train_dir=TRAIN_DIR,
        val_dir=VAL_DIR,
        test_dir=TEST_DIR,
        **config
    )

    early_stopping = EarlyStopping(patience=10, min_delta=0.001, mode='min')
    checkpoint_name = f'Single_best_{config["model_name"]}.pth'
    model_checkpoint = ModelCheckpoint(filepath=checkpoint_name, monitor='val_loss', mode='min', save_best_only=True)
    reduce_lr = ReduceLROnPlateau(optimizer=trainer.optimizer, monitor='val_loss', mode='min', factor=0.5, patience=5, min_lr=1e-6, verbose=1)

    trainer.add_callback(early_stopping)
    trainer.add_callback(model_checkpoint)
    trainer.add_callback(reduce_lr)

    best_model_path = trainer.train()
    if best_model_path:
        plot_training_history(trainer, save_path='training_history.png')

    return best_model_path

# %%
# 1. Cell này dùng để Train (Comment lại nếu không muốn chạy lại)
print("Running Training Step...")
best_model_path = run_training()
# Out:
# Running Training Step...
# 🚀 Starting Training Process with Advanced Losses...
# Number of classes: 14
# Using Focal Loss (alpha=1.0, gamma=2.0)
# Adding Center Loss
# Adding CORAL Loss
# Model: densenet201
# Device: cuda
# Adding CenterLoss centers to optimizer
# Start training...
# ==================================================
# Training: 100%|██████████| 246/246 [02:20<00:00,  1.75it/s, Loss
# Validation: 100%|██████████| 26/26 [00:05<00:00,  5.08it/s, Loss=1.3667, Acc=78.45%]
# 💾 Saved best model at epoch 19
# Epoch 19/50
# Train Loss: 0.0821, Train Acc: 95.26%
# Val Loss: 0.6983, Val Acc: 78.45%
# Val Precision: 73.52%, Val Recall: 66.89%, Val F1: 68.76%
# LR: 0.000713, Time: 146.42s
# ----------------------------------------------------------------------
# Training:   5%|▌         | 13/246 [00:08<02:36,  1.49it/s, Loss=0.0573, Acc=97.00%]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2505184746.py in <cell line: 0>()
#       1 # 1. Cell này dùng để Train (Comment lại nếu không muốn chạy lại)
#       2 print("Running Training Step...")
# ----> 3 best_model_path = run_training()
#
# /tmp/ipython-input-1650417125.py in run_training(config)
#      69     trainer.add_callback(reduce_lr)
#      70
# ---> 71     best_model_path = trainer.train()
#      72     if best_model_path:
#      73         plot_training_history(trainer, save_path='training_history.png')
#
# /tmp/ipython-input-1865573404.py in train(self)
#     221         for epoch in range(self.epochs):
#     222             start_time = time.time()
# --> 223             train_loss, train_acc = self.train_epoch()
#     224             val_loss, val_acc, val_precision, val_recall, val_f1, _, _ = self.validate_epoch(self.val_loader, "Validation")
#     225             current_lr = self.optimizer.param_groups[0]['lr']
#
# /tmp/ipython-input-1865573404.py in train_epoch(self)
#     173             loss = self.criterion(logits, labels, features)
#     174
# --> 175             loss.backward()
#     176             self.optimizer.step()
#     177
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     623                 inputs=inputs,
#     624             )
# --> 625         torch.autograd.backward(
#     626             self, gradient, retain_graph, create_graph, inputs=inputs
#     627         )
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     352     # some Python versions print out the first line of a multi-line function
#     353     # calls in the traceback and some print out the last line
# --> 354     _engine_run_backward(
#     355         tensors,
#     356         grad_tensors_,
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     839         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     840     try:
# --> 841         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     842             t_outputs, *args, **kwargs
#     843         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %% [markdown]
# # **KIỂM TRA VỚI DỮ LIỆU CỦA 4 TỆP**

# %% [markdown]
# **0) VỚI TỆP MẶC ĐỊNH**

# %%
def run_testing(model_path, config=DEFAULT_CONFIG):
    """Run testing process separately"""
    print(f"🚀 Starting Testing Process using model: {model_path}...")

    if not os.path.exists(model_path):
        print(f"❌ Model path not found: {model_path}")
        return

    # Initialize trainer (for dataloaders and model structure)
    trainer = ModelTrainer(
        train_dir=TRAIN_DIR,
        val_dir=VAL_DIR,
        test_dir=TEST_DIR,
        **config
    )

    # Evaluate on test set
    test_predicted, test_labels, metrics = trainer.evaluate_on_test(model_path)

    # Plot confusion matrix with scientific names
    plot_confusion_matrix(
        test_labels,
        test_predicted,
        trainer.class_names,
        save_path='test_confusion_matrix.png',
        scientific_names=SCIENTIFIC_NAMES,
        normalize_per_row=True
    )

    # Global scale confusion matrix
    plot_confusion_matrix(
        test_labels,
        test_predicted,
        trainer.class_names,
        save_path='test_confusion_matrix_global.png',
        scientific_names=SCIENTIFIC_NAMES,
        normalize_per_row=False
    )

    # Print final results
    print(f"\n🎉 FINAL TEST RESULTS:")
    print(f"   Accuracy: {metrics['test_accuracy']:.2f}%")
    print(f"   Precision: {metrics['test_precision']:.2f}%")
    print(f"   Recall: {metrics['test_recall']:.2f}%")
    print(f"   F1-Score: {metrics['test_f1_score']:.2f}%")

    return metrics

# %%
TEST_DIR = "/content/Single/test"

# 2. Cell này dùng để Test riêng biệt
print("Running Testing Step...")

# Sử dụng model đã lưu từ lần train trước
model_path = f"Single_best_{DEFAULT_CONFIG['model_name']}.pth"
# model_path = "/content/drive/MyDrive/PlantIdentification/saved_models/Single_best_densenet201.pth"

# Chạy test
run_testing(model_path)
# Out:
# Running Testing Step...
# 🚀 Starting Testing Process using model: Single_best_densenet201.pth...
# Number of classes: 14
# Using Focal Loss (alpha=1.0, gamma=2.0)
# Adding Center Loss
# Adding CORAL Loss
# Model: densenet201
# Device: cuda
# Adding CenterLoss centers to optimizer
# Loading model from Single_best_densenet201.pth
#
# ======================================================================
# 🧪 EVALUATING ON TEST SET
# ======================================================================
# Testing: 100%|██████████| 17/17 [00:03<00:00,  4.81it/s, Loss=22.7067, Acc=74.18%]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 🎯 DETAILED TEST RESULTS
# ======================================================================
# Overall Accuracy: 74.18%
# Overall Precision (Macro): 63.78%
# Overall Recall (Macro): 55.08%
# Overall F1-Score (Macro): 57.04%
# ======================================================================
#
# 📊 PER-CLASS METRICS:
# ----------------------------------------------------------------------
# Class                Precision    Recall       F1-Score     Support
# ----------------------------------------------------------------------
# Bằng lăng            86.67      % 61.90      % 72.22      % 21
# Gội                  41.67      % 34.88      % 37.97      % 43
# Gội trắng            75.00      % 51.72      % 61.22      % 58
# Keo Lá Tràm ( Rụng Lá) 56.25      % 56.25      % 56.25      % 16
# Keo lá tràm          85.92      % 95.81      % 90.59      % 191
# Lát Hoa              80.85      % 90.48      % 85.39      % 126
# Phượng vĩ            92.68      % 92.68      % 92.68      % 41
# Re hương             41.09      % 68.60      % 51.39      % 121
# Sấu                  56.73      % 59.00      % 57.84      % 100
# Sồi Phảng            0.00       % 0.00       % 0.00       % 46
# Sữa                  80.00      % 36.36      % 50.00      % 11
# Thông mã vĩ          96.06      % 90.04      % 92.95      % 271
# Vả                   100.00     % 33.33      % 50.00      % 3
# Đa                   0.00       % 0.00       % 0.00       % 21
# ----------------------------------------------------------------------
#
# 📈 CLASSIFICATION REPORT:
#                         precision    recall  f1-score   support
#
#              Bằng lăng     0.8667    0.6190    0.7222        21
#                    Gội     0.4167    0.3488    0.3797        43
#              Gội trắng     0.7500    0.5172    0.6122        58
# Keo Lá Tràm ( Rụng Lá)     0.5625    0.5625    0.5625        16
#            Keo lá tràm     0.8592    0.9581    0.9059       191
#                Lát Hoa     0.8085    0.9048    0.8539       126
#              Phượng vĩ     0.9268    0.9268    0.9268        41
#               Re hương     0.4109    0.6860    0.5139       121
#                    Sấu     0.5673    0.5900    0.5784       100
#              Sồi Phảng     0.0000    0.0000    0.0000        46
#                    Sữa     0.8000    0.3636    0.5000        11
#            Thông mã vĩ     0.9606    0.9004    0.9295       271
#                     Vả     1.0000    0.3333    0.5000         3
#                     Đa     0.0000    0.0000    0.0000        21
#
#               accuracy                         0.7418      1069
#              macro avg     0.6378    0.5508    0.5704      1069
#           weighted avg     0.7214    0.7418    0.7236      1069
#
#
# 💾 Test metrics saved to test_metrics.json
# 📊 Confusion matrix saved to test_confusion_matrix.png
# 📊 Confusion matrix saved to test_confusion_matrix_global.png
# 🎉 FINAL TEST RESULTS:
#    Accuracy: 74.18%
#    Precision: 63.78%
#    Recall: 55.08%
#    F1-Score: 57.04%
# {'test_accuracy': 74.18147801683817,
#  'test_precision': 63.77969194412714,
#  'test_recall': 55.07586912745588,
#  'test_f1_score': 57.03788194902797,
#  'per_class_metrics': {'Bằng lăng': {'precision': 86.66666666666667,
#    'recall': 61.904761904761905,
#    'f1_score': 72.22222222222221,
#    'support': 21},
#   'Gội': {'precision': 41.66666666666667,
#    'recall': 34.883720930232556,
#    'f1_score': 37.9746835443038,
#    'support': 43},
#   'Gội trắng': {'precision': 75.0,
#    'recall': 51.724137931034484,
#    'f1_score': 61.224489795918366,
#    'support': 58},
#   'Keo Lá Tràm ( Rụng Lá)': {'precision': 56.25,
#    'recall': 56.25,
#    'f1_score': 56.25,
#    'support': 16},
#   'Keo lá tràm': {'precision': 85.91549295774648,
#    'recall': 95.81151832460732,
#    'f1_score': 90.5940594059406,
#    'support': 191},
#   'Lát Hoa': {'precision': 80.85106382978722,
#    'recall': 90.47619047619048,
#    'f1_score': 85.39325842696628,
#    'support': 126},
#   'Phượng vĩ': {'precision': 92.6829268292683,
#    'recall': 92.6829268292683,
#    'f1_score': 92.6829268292683,
#    'support': 41},
#   'Re hương': {'precision': 41.089108910891085,
#    'recall': 68.59504132231406,
#    'f1_score': 51.39318885448917,
#    'support': 121},
#   'Sấu': {'precision': 56.730769230769226,
#    'recall': 59.0,
#    'f1_score': 57.84313725490197,
#    'support': 100},
#   'Sồi Phảng': {'precision': 0.0,
#    'recall': 0.0,
#    'f1_score': 0.0,
#    'support': 46},
#   'Sữa': {'precision': 80.0,
#    'recall': 36.36363636363637,
#    'f1_score': 50.0,
#    'support': 11},
#   'Thông mã vĩ': {'precision': 96.06299212598425,
#    'recall': 90.03690036900369,
#    'f1_score': 92.95238095238095,
#    'support': 271},
#   'Vả': {'precision': 100.0,
#    'recall': 33.33333333333333,
#    'f1_score': 50.0,
#    'support': 3},
#   'Đa': {'precision': 0.0, 'recall': 0.0, 'f1_score': 0.0, 'support': 21}}}

# %% [markdown]
# **1) VỚI TỆP 22/05**

# %%
# !unzip /content/drive/MyDrive/PlantIdentification/Patches/VNUF_134_Patches.zip
# Out:
# Archive:  /content/drive/MyDrive/PlantIdentification/Patches/VNUF_134_Patches.zip
#    creating: VNUF_134_Patches/
# VNUF_134_Patches/Bằng lăng/:  mismatching "local" filename (VNUF_134_Patches/Bс║▒ng l─Гng/),
#          continuing with "central" filename version
#    creating: VNUF_134_Patches/Bằng lăng/
# VNUF_134_Patches/Bằng lăng/248_patch1.png:  mismatching "local" filename (VNUF_134_Patches/Bс║▒ng l─Гng/248_patch1.png),
#          continuing with "central" filename version
#   inflating: VNUF_134_Patches/Bằng lăng/248_patch1.png
# VNUF_134_Patches/Bằng lăng/248_patch3.png:  mismatching "local" filename (VNUF_134_Patches/Bс║▒ng l─Гng/248_patch3.png),
#          continuing with "central" filename version
#   inflating: VNUF_134_Patches/Bằng lăng/248_patch3.png
# VNUF_134_Patches/Bằng lăng/248_patch4.png:  mismatching "local" filename (VNUF_134_Patches/Bс║▒ng l─Гng/248_patch4.png),
#          continuing with "central" filename version
#   inflating: VNUF_134_Patches/Bằng lăng/248_patch4.png
# VNUF_134_Patches/Bằng lăng/248_patch5.png:  mismatching "local" filename (VNUF_134_Patches/Bс║▒ng l─Гng/248_patch5.png),
#          continuing with "central" filename version
#   inflating: VNUF_134_Patches/Bằng lăng/248_patch5.png
# VNUF_134_Patches/Bằng lăng/248_patch6.png:  mismatching "local" filename (VNUF_134_Patches/Bс║▒ng l─Гng/248_patch6.png),
#          continuing with "central" filename version
#   inflating: VNUF_134_Patches/Bằng lăng/248_patch6.png
# VNUF_134_Patches/Bằng lăng/472_patch1.png:  mismatching "local" filename (VNUF_134_Patches/Bс║▒ng l─Гng/472_patch1.png),
#          continuing with "central" filename version
#   inflating: VNUF_134_Patches/Bằng lăng/472_patch1.png
# VNUF_134_Patches/Bằng lăng/472_patch2.png:  mismatching "local" filename (VNUF_134_Patches/
patch1.png),
#          continuing with "central" filename version
#   inflating: VNUF_134_Patches/Sồi Phảng/15_patch1.png
# VNUF_134_Patches/Sồi Phảng/315_patch1.png:  mismatching "local" filename (VNUF_134_Patches/Sс╗Уi Phс║гng/315_patch1.png),
#          continuing with "central" filename version
#   inflating: VNUF_134_Patches/Sồi Phảng/315_patch1.png
# VNUF_134_Patches/Sồi Phảng/315_patch2.png:  mismatching "local" filename (VNUF_134_Patches/Sс╗Уi Phс║гng/315_patch2.png),
#          continuing with "central" filename version
#   inflating: VNUF_134_Patches/Sồi Phảng/315_patch2.png
# VNUF_134_Patches/Sữa/:  mismatching "local" filename (VNUF_134_Patches/Sс╗пa/),
#          continuing with "central" filename version
#    creating: VNUF_134_Patches/Sữa/
# VNUF_134_Patches/Sữa/114_patch1.png:  mismatching "local" filename (VNUF_134_Patches/Sс╗пa/114_patch1.png),
#          continuing with "central" filename version
#   inflating: VNUF_134_Patches/Sữa/114_patch1.png
# VNUF_134_Patches/Sữa/115_patch1.png:  mismatching "local" filename (VNUF_134_Patches/Sс╗пa/115_patch1.png),
#          continuing with "central" filename version
#   inflating: VNUF_134_Patches/Sữa/115_patch1.png
# VNUF_134_Patches/Sữa/260_patch1.png:  mismatching "local" filename (VNUF_134_Patches/Sс╗пa/260_patch1.png),
#          continuing with "central" filename version
#   inflating: VNUF_134_Patches/Sữa/260_patch1.png
# VNUF_134_Patches/Sữa/377_patch1.png:  mismatching "local" filename (VNUF_134_Patches/Sс╗пa/377_patch1.png),
#          continuing with "central" filename version
#   inflating: VNUF_134_Patches/Sữa/377_patch1.png
# VNUF_134_Patches/Thông mã vĩ/:  mismatching "local" filename (VNUF_134_Patches/Th├┤ng m├г v─й/),
#          continuing with "central" filename version
#    creating: VNUF_134_Patches/Thông mã vĩ/
# VNUF_134_Patches/Thông mã vĩ/210_patch1.png:  mismatching "local" filename (VNUF_134_Patches/Th├┤ng m├г v─й/210_patch1.png),
#          continuing with "central" filename version
#   inflating: VNUF_134_Patches/Thông mã vĩ/210_patch1.png
# VNUF_134_Patches/Thông mã vĩ/224_patch1.png:  mismatching "local" filename (VNUF_134_Patches/Th├┤ng m├г v─й/224_patch1.png),
#          continuing with "central" filename version
#   inflating: VNUF_134_Patches/Thông mã vĩ/224_patch1.png
# VNUF_134_Patches/Thông mã vĩ/224_patch2.png:  mismatching "local" filename (VNUF_134_Patches/Th├┤ng m├г v─й/224_patch2.png),
#          continuing with "central" filename version
#   inflating: VNUF_134_Patches/Thông mã vĩ/224_patch2.png
# VNUF_134_Patches/Thông mã vĩ/233_patch1.png:  mismatching "local" filename (VNUF_134_Patches/Th├┤ng m├г v─й/233_patch1.png),
#          continuing with "central" filename version
#   inflating: VNUF_134_Patches/Thông mã vĩ/233_patch1.png
# VNUF_134_Patches/Thông mã vĩ/233_patch2.png:  mismatching "local" filename (VNUF_134_Patches/Th├┤ng m├г v─й/233_patch2.png),
#          continuing with "central" filename version
#   inflating: VNUF_134_Patches/Thông mã vĩ/233_patch2.png
# VNUF_134_Patches/Thông mã vĩ/233_patch3.png:  mismatching "local" filename (VNUF_134_Patches/Th├┤ng m├г v─й/233_patch3.png),
#          continuing with "central" filename version
#   inflating: VNUF_134_Patches/Thông mã vĩ/233_patch3.png
# VNUF_134_Patches/Thông mã vĩ/233_patch4.png:  mismatching "local" filename (VNUF_134_Patches/Th├┤ng m├г v─й/233_patch4.png),
#          continuing with "central" filename version
#   inflating: VNUF_134_Patches/Thông mã vĩ/233_patch4.png
# VNUF_134_Patches/Thông mã vĩ/233_patch5.png:  mismatching "local" filename (VNUF_134_Patches/Th├┤ng m├г v─й/233_patch5.png),
#          continuing with "central" filename version
#   inflating: VNUF_134_Patches/Thông mã vĩ/233_patch5.png
# VNUF_134_Patches/Thông mã vĩ/233_patch6.png:  mismatching "local" filename (VNUF_134_Patches/Th├┤ng m├г v─й/233_patch6.png),
#          continuing with "central" filename version
#   inflating: VNUF_134_Patches/Thông mã vĩ/233_patch6.png
# VNUF_134_Patches/Vả/:  mismatching "local" filename (VNUF_134_Patches/Vс║г/),
#          continuing with "central" filename version
#    creating: VNUF_134_Patches/Vả/
# VNUF_134_Patches/Vả/122_patch1.png:  mismatching "local" filename (VNUF_134_Patches/Vс║г/122_patch1.png),
#          continuing with "central" filename version
#   inflating: VNUF_134_Patches/Vả/122_patch1.png
# VNUF_134_Patches/Đa/:  mismatching "local" filename (VNUF_134_Patches/─Рa/),
#          continuing with "central" filename version
#    creating: VNUF_134_Patches/Đa/
# VNUF_134_Patches/Đa/120_patch1.png:  mismatching "local" filename (VNUF_134_Patches/─Рa/120_patch1.png),
#          continuing with "central" filename version
#   inflating: VNUF_134_Patches/Đa/120_patch1.png
# VNUF_134_Patches/Đa/367_patch1.png:  mismatching "local" filename (VNUF_134_Patches/─Рa/367_patch1.png),
#          continuing with "central" filename version
#   inflating: VNUF_134_Patches/Đa/367_patch1.png
# VNUF_134_Patches/Đa/367_patch2.png:  mismatching "local" filename (VNUF_134_Patches/─Рa/367_patch2.png),
#          continuing with "central" filename version
#   inflating: VNUF_134_Patches/Đa/367_patch2.png
# VNUF_134_Patches/Đa/368_patch1.png:  mismatching "local" filename (VNUF_134_Patches/─Рa/368_patch1.png),
#          continuing with "central" filename version
#   inflating: VNUF_134_Patches/Đa/368_patch1.png
# VNUF_134_Patches/Đa/368_patch2.png:  mismatching "local" filename (VNUF_134_Patches/─Рa/368_patch2.png),
#          continuing with "central" filename version
#   inflating: VNUF_134_Patches/Đa/368_patch2.png

# %%
# !rm -rf /content/VNUF_134_Patches/Sếu

# %%
TEST_DIR = "/content/VNUF_134_Patches"

# 2. Cell này dùng để Test riêng biệt
print("Running Testing Step...")

# Sử dụng model đã lưu từ lần train trước
model_path = f"Single_best_{DEFAULT_CONFIG['model_name']}.pth"
# model_path = "/content/drive/MyDrive/PlantIdentification/saved_models/Single_best_densenet201.pth"

# Chạy test
run_testing(model_path)
# Out:
# Running Testing Step...
# 🚀 Starting Testing Process using model: Single_best_densenet201.pth...
# Number of classes: 14
# Using Focal Loss (alpha=1.0, gamma=2.0)
# Adding Center Loss
# Adding CORAL Loss
# Model: densenet201
# Device: cuda
# Adding CenterLoss centers to optimizer
# Loading model from Single_best_densenet201.pth
#
# ======================================================================
# 🧪 EVALUATING ON TEST SET
# ======================================================================
# Testing: 100%|██████████| 10/10 [00:02<00:00,  4.37it/s, Loss=25.2491, Acc=41.07%]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 🎯 DETAILED TEST RESULTS
# ======================================================================
# Overall Accuracy: 41.07%
# Overall Precision (Macro): 26.28%
# Overall Recall (Macro): 25.94%
# Overall F1-Score (Macro): 25.09%
# ======================================================================
#
# 📊 PER-CLASS METRICS:
# ----------------------------------------------------------------------
# Class                Precision    Recall       F1-Score     Support
# ----------------------------------------------------------------------
# Bằng lăng            100.00     % 100.00     % 100.00     % 7
# Gội                  12.50      % 2.27       % 3.85       % 44
# Gội trắng            11.11      % 6.67       % 8.33       % 45
# Keo Lá Tràm ( Rụng Lá) 87.50      % 63.64      % 73.68      % 11
# Keo lá tràm          50.71      % 85.03      % 63.53      % 167
# Lát Hoa              26.98      % 33.33      % 29.82      % 51
# Phượng vĩ            48.39      % 52.45      % 50.34      % 143
# Re hương             20.00      % 6.74       % 10.08      % 89
# Sấu                  2.33       % 1.89       % 2.08       % 53
# Sồi Phảng            0.00       % 0.00       % 0.00       % 4
# Sữa                  0.00       % 0.00       % 0.00       % 4
# Thông mã vĩ          8.33       % 11.11      % 9.52       % 9
# Vả                   0.00       % 0.00       % 0.00       % 1
# Đa                   0.00       % 0.00       % 0.00       % 5
# ----------------------------------------------------------------------
#
# 📈 CLASSIFICATION REPORT:
#                         precision    recall  f1-score   support
#
#              Bằng lăng     1.0000    1.0000    1.0000         7
#                    Gội     0.1250    0.0227    0.0385        44
#              Gội trắng     0.1111    0.0667    0.0833        45
# Keo Lá Tràm ( Rụng Lá)     0.8750    0.6364    0.7368        11
#            Keo lá tràm     0.5071    0.8503    0.6353       167
#                Lát Hoa     0.2698    0.3333    0.2982        51
#              Phượng vĩ     0.4839    0.5245    0.5034       143
#               Re hương     0.2000    0.0674    0.1008        89
#                    Sấu     0.0233    0.0189    0.0208        53
#              Sồi Phảng     0.0000    0.0000    0.0000         4
#                    Sữa     0.0000    0.0000    0.0000         4
#            Thông mã vĩ     0.0833    0.1111    0.0952         9
#                     Vả     0.0000    0.0000    0.0000         1
#                     Đa     0.0000    0.0000    0.0000         5
#
#               accuracy                         0.4107       633
#              macro avg     0.2628    0.2594    0.2509       633
#           weighted avg     0.3390    0.4107    0.3551       633
#
#
# 💾 Test metrics saved to test_metrics.json
# 📊 Confusion matrix saved to test_confusion_matrix.png
# 📊 Confusion matrix saved to test_confusion_matrix_global.png
# 🎉 FINAL TEST RESULTS:
#    Accuracy: 41.07%
#    Precision: 26.28%
#    Recall: 25.94%
#    F1-Score: 25.09%
# {'test_accuracy': 41.07424960505529,
#  'test_precision': 26.275395379457112,
#  'test_recall': 25.93757571957521,
#  'test_f1_score': 25.089262976065086,
#  'per_class_metrics': {'Bằng lăng': {'precision': 100.0,
#    'recall': 100.0,
#    'f1_score': 100.0,
#    'support': 7},
#   'Gội': {'precision': 12.5,
#    'recall': 2.272727272727273,
#    'f1_score': 3.8461538461538463,
#    'support': 44},
#   'Gội trắng': {'precision': 11.11111111111111,
#    'recall': 6.666666666666667,
#    'f1_score': 8.333333333333332,
#    'support': 45},
#   'Keo Lá Tràm ( Rụng Lá)': {'precision': 87.5,
#    'recall': 63.63636363636363,
#    'f1_score': 73.68421052631578,
#    'support': 11},
#   'Keo lá tràm': {'precision': 50.71428571428571,
#    'recall': 85.02994011976048,
#    'f1_score': 63.534675615212535,
#    'support': 167},
#   'Lát Hoa': {'precision': 26.984126984126984,
#    'recall': 33.33333333333333,
#    'f1_score': 29.82456140350877,
#    'support': 51},
#   'Phượng vĩ': {'precision': 48.38709677419355,
#    'recall': 52.44755244755245,
#    'f1_score': 50.33557046979866,
#    'support': 143},
#   'Re hương': {'precision': 20.0,
#    'recall': 6.741573033707865,
#    'f1_score': 10.084033613445378,
#    'support': 89},
#   'Sấu': {'precision': 2.3255813953488373,
#    'recall': 1.8867924528301887,
#    'f1_score': 2.083333333333333,
#    'support': 53},
#   'Sồi Phảng': {'precision': 0.0,
#    'recall': 0.0,
#    'f1_score': 0.0,
#    'support': 4},
#   'Sữa': {'precision': 0.0, 'recall': 0.0, 'f1_score': 0.0, 'support': 4},
#   'Thông mã vĩ': {'precision': 8.333333333333332,
#    'recall': 11.11111111111111,
#    'f1_score': 9.523809523809524,
#    'support': 9},
#   'Vả': {'precision': 0.0, 'recall': 0.0, 'f1_score': 0.0, 'support': 1},
#   'Đa': {'precision': 0.0, 'recall': 0.0, 'f1_score': 0.0, 'support': 5}}}

# %% [markdown]
# **2) VỚI TỆP 10/08**

# %%
# !unzip /content/drive/MyDrive/PlantIdentification/Patches/VNUF_234_Patches.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#          continuing with "central" filename version
#   inflating: VNUF_234_Patches/Gội trắng/233_patch2.png
# VNUF_234_Patches/Gội trắng/279_patch1.png:  mismatching "local" filename (VNUF_234_Patches/Gс╗Щi trс║пng/279_patch1.png),
#          continuing with "central" filename version
#   inflating: VNUF_234_Patches/Gội trắng/279_patch1.png
# VNUF_234_Patches/Gội trắng/279_patch2.png:  mismatching "local" filename (VNUF_234_Patches/Gс╗Щi trс║пng/279_patch2.png),
#          continuing with "central" filename version
#   inflating: VNUF_234_Patches/Gội trắng/279_patch2.png
# VNUF_234_Patches/Gội trắng/284_patch1.png:  mismatching "local" filename (VNUF_234_Patches/Gс╗Щi trс║пng/284_patch1.png),
#          continuing with "central" filename version
#   inflating: VNUF_234_Patches/Gội trắng/284_patch1.png
# VNUF_234_Patches/Gội trắng/284_patch10.png:  mismatching "local" filename (VNUF_234_Patches/Gс╗Щi trс║пng/284_patch10.png),
#          continuing with "central" filename version
#   inflating: VNUF_234_Patches/Gội trắng/284_patch10.png
# VNUF_234_Patches/Gội trắng/284_patch11.png:  mismatching "local" filename (VNUF_234_Patches/Gс╗Щi trс║пng/284_patch11.png),
#          continuing with "central" filename version
#   inflating: VNUF_234_Patches/Gội trắng/284_patch11.png
# VNUF_234_Patches/Gội trắng/284_patch12.png:  mismatching "local" filename (VNUF_234_Patches/Gс╗Щi trс║пng/284_patch12.png),
#          continuing with "central" filename version
#   inflating: VNUF_234_Patches/Gội trắng/284_patch12.png
# VNUF_234_Patches/Gội trắng/284_patch2.png:  mismatching "local" filename (VNUF_234_Patches/Gс╗Щi trс║пng/284_patch2.png),
#          continuing with "central" filename version
#   inflating: VNUF_234_Patches/Gội trắng/284_patch2.png
# VNUF_234_Patches/Gội trắng/284_patch3.png:  mismatching "local" filename (VNUF_234_Patches/Gс╗Щi trс║пng/284_patch3.png),
#          continuing with "central" filename version
#   inflating: VNUF_234_Patches/Gội trắng/284_patch3.png
# VNUF_234_Patches/Gội trắng/284_patch4.png:  mismatching "local" filename (VNUF_234_Patches/Gс╗Щi trс║пng/284_patch4.png),
#          continuing with "central" filename version
#   inflating: VNUF_234_Patches/Gội trắng/284_patch4.png
# VNUF_234_Patches/Gội trắng/284_patch5.png:  mismatching "local" filename (VNUF_234_Patches/Gс╗Щi trс║пng/284_patch5.png),
#          continuing with "central" filename version
#   inflating: VNUF_234_Patches/Gội trắng/284_patch5.png
# VNUF_234_Patches/Gội trắng/284_patch6.png:  mismatching "local" filename (VNUF_234_Patches/Gс╗Щi trс║пng/284_patch6.png),
#          continuing with "central" filename version
#   inflating: VNUF_234_Patches/Gội trắng/284_patch6.png
# VNUF_234_Patches/Gội trắng/284_patch7.png:  mismatching "local" filename (VNUF_234_Patches/Gс╗Щi trс║пng/284_patch7.png),
#          continuing with "central" filename version
#   inflating: VNUF_234_Patches/Gội trắng/284_patch7.png
# VNUF_234_Patches/Gội trắng/284_patch8.png:  mismatching "local" filename (VNUF_234_Patches/Gс╗Щi trс║пng/284_patch8.png),
#          continuing with "central" filename version
#   inflating: VNUF_234_Patches/Gội trắng/284_patch8.png
# VNUF_234_Patches/Gội trắng/284_patch9.png:  mismatching "local" filename (VNUF_234_Patches/Gс╗Щi trс║пng/284_patch9.png),
#          continuing with "central" filename version
#   inflating: VNUF_234_Patches/Gội trắng/284_patch9.png
# VNUF_234_Patches/Gội trắng/288_patch1.png:  mismatching "local" filename (VNUF_234_Patches/Gс╗Щi trс║пng/288_patch1.png),
#          continuing with "central" filename version
#   inflating: VNUF_234_Patches/Gội trắng/288_patch1.png
# VNUF_234_Patches/Gội trắng/288_patch2.png:  mismatching "local" filename (VNUF_234_Patches/Gс╗Щi trс║пng/288_patch2.png),
#          continuing with "central" filename version
#   inflating: VNUF_234_Patches/Gội trắng/288_patch2.png
# VNUF_234_Patches/Gội trắng/288_patch3.png:  mismatching "local" filename (VNUF_234_Patches/Gс╗Щi trс║пng/288_patch3.png),
#          continuing with "central" filename version
#   inflating: VNUF_234_Patches/Gội trắng/288_patch3.png
# VNUF_234_Patches/Gội trắng/288_patch4.png:  mismatching "local" filename (VNUF_234_Patches/Gс╗Щi trс║пng/288_patch4.png),
#          continuing with "central" filename version
#   inflating: VNUF_234_Patches/Gội trắng/288_patch4.png
# VNUF_234_Patches/Gội trắng/288_patch5.png:  mismatching "local" filename (VNUF_234_Patches/Gс╗Щi trс║пng/288_patch5.png),
#          continuing with "central" filename version
#   inflating: VNUF_234_Patches/Gội trắng/288_patch5.png
# VNUF_234_Patches/Gội trắng/288_patch6.png:  mismatching "local" filename (VNUF_234_Patches/Gс╗Щi trс║пng/288_patch6.png),
#          continuing with "central" filename version
#   inflating: VNUF_234_Patches/Gội trắng/288_patch6.png
# VNUF_234_Patches/Gội trắng/291_patch1.png:  mismatching "local" filename (VNUF_234_Patches/Gс╗Щi trс║пng/291_patch1.png),
#          continuing with "central" filename version
#   inflating: VNUF_234_Patches/Gội trắng
patch1.png),
#          continuing with "central" filename version
#   inflating: VNUF_234_Patches/Đa/71_patch1.png
# VNUF_234_Patches/Đa/82_patch1.png:  mismatching "local" filename (VNUF_234_Patches/─Рa/82_patch1.png),
#          continuing with "central" filename version
#   inflating: VNUF_234_Patches/Đa/82_patch1.png
# VNUF_234_Patches/Đa/82_patch2.png:  mismatching "local" filename (VNUF_234_Patches/─Рa/82_patch2.png),
#          continuing with "central" filename version
#   inflating: VNUF_234_Patches/Đa/82_patch2.png

# %%
# !rm -rf /content/VNUF_234_Patches/Sếu

# %%
TEST_DIR = "/content/VNUF_234_Patches"

def run_testing(model_path, config=DEFAULT_CONFIG):
    """Run testing process separately"""
    print(f"🚀 Starting Testing Process using model: {model_path}...")

    if not os.path.exists(model_path):
        print(f"❌ Model path not found: {model_path}")
        return

    # Initialize trainer (for dataloaders and model structure)
    trainer = ModelTrainer(
        train_dir=TRAIN_DIR,
        val_dir=VAL_DIR,
        test_dir=TEST_DIR,
        **config
    )

    # Evaluate on test set
    test_predicted, test_labels, metrics = trainer.evaluate_on_test(model_path)

    # Plot confusion matrix with scientific names
    plot_confusion_matrix(
        test_labels,
        test_predicted,
        trainer.class_names,
        save_path='test_confusion_matrix.png',
        scientific_names=SCIENTIFIC_NAMES,
        normalize_per_row=True
    )

    # Global scale confusion matrix
    plot_confusion_matrix(
        test_labels,
        test_predicted,
        trainer.class_names,
        save_path='test_confusion_matrix_global.png',
        scientific_names=SCIENTIFIC_NAMES,
        normalize_per_row=False
    )

    # Print final results
    print(f"\n🎉 FINAL TEST RESULTS:")
    print(f"   Accuracy: {metrics['test_accuracy']:.2f}%")
    print(f"   Precision: {metrics['test_precision']:.2f}%")
    print(f"   Recall: {metrics['test_recall']:.2f}%")
    print(f"   F1-Score: {metrics['test_f1_score']:.2f}%")

    return metrics

# %%
TEST_DIR = "/content/VNUF_234_Patches"
# 2. Cell này dùng để Test riêng biệt
print("Running Testing Step...")

# Sử dụng model đã lưu từ lần train trước
model_path = f"Single_best_{DEFAULT_CONFIG['model_name']}.pth"
# model_path = "/content/drive/MyDrive/PlantIdentification/saved_models/Single_best_densenet201.pth"

# Chạy test
run_testing(model_path)
# Out:
# Running Testing Step...
# 🚀 Starting Testing Process using model: Single_best_densenet201.pth...
# Number of classes: 14
# Using Focal Loss (alpha=1.0, gamma=2.0)
# Adding Center Loss
# Adding CORAL Loss
# Model: densenet201
# Device: cuda
# Adding CenterLoss centers to optimizer
# Loading model from Single_best_densenet201.pth
#
# ======================================================================
# 🧪 EVALUATING ON TEST SET
# ======================================================================
# Testing: 100%|██████████| 37/37 [00:07<00:00,  5.15it/s, Loss=23.0915, Acc=55.03%]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 🎯 DETAILED TEST RESULTS
# ======================================================================
# Overall Accuracy: 55.03%
# Overall Precision (Macro): 33.73%
# Overall Recall (Macro): 37.25%
# Overall F1-Score (Macro): 33.57%
# ======================================================================
#
# 📊 PER-CLASS METRICS:
# ----------------------------------------------------------------------
# Class                Precision    Recall       F1-Score     Support
# ----------------------------------------------------------------------
# Bằng lăng            28.99      % 64.52      % 40.00      % 31
# Gội                  47.83      % 28.21      % 35.48      % 117
# Gội trắng            32.82      % 35.54      % 34.13      % 121
# Keo Lá Tràm ( Rụng Lá) 58.97      % 95.83      % 73.02      % 24
# Keo lá tràm          92.26      % 73.01      % 81.52      % 604
# Lát Hoa              34.75      % 60.29      % 44.09      % 204
# Phượng vĩ            28.81      % 9.88       % 14.72      % 172
# Re hương             41.01      % 66.35      % 50.69      % 416
# Sấu                  17.28      % 12.39      % 14.43      % 226
# Sồi Phảng            0.00       % 0.00       % 0.00       % 12
# Sữa                  0.00       % 0.00       % 0.00       % 15
# Thông mã vĩ          89.52      % 75.51      % 81.92      % 396
# Vả                   0.00       % 0.00       % 0.00       % 4
# Đa                   0.00       % 0.00       % 0.00       % 26
# ----------------------------------------------------------------------
#
# 📈 CLASSIFICATION REPORT:
#                         precision    recall  f1-score   support
#
#              Bằng lăng     0.2899    0.6452    0.4000        31
#                    Gội     0.4783    0.2821    0.3548       117
#              Gội trắng     0.3282    0.3554    0.3413       121
# Keo Lá Tràm ( Rụng Lá)     0.5897    0.9583    0.7302        24
#            Keo lá tràm     0.9226    0.7301    0.8152       604
#                Lát Hoa     0.3475    0.6029    0.4409       204
#              Phượng vĩ     0.2881    0.0988    0.1472       172
#               Re hương     0.4101    0.6635    0.5069       416
#                    Sấu     0.1728    0.1239    0.1443       226
#              Sồi Phảng     0.0000    0.0000    0.0000        12
#                    Sữa     0.0000    0.0000    0.0000        15
#            Thông mã vĩ     0.8952    0.7551    0.8192       396
#                     Vả     0.0000    0.0000    0.0000         4
#                     Đa     0.0000    0.0000    0.0000        26
#
#               accuracy                         0.5503      2368
#              macro avg     0.3373    0.3725    0.3357      2368
#           weighted avg     0.5746    0.5503    0.5440      2368
#
#
# 💾 Test metrics saved to test_metrics.json
# 📊 Confusion matrix saved to test_confusion_matrix.png
# 📊 Confusion matrix saved to test_confusion_matrix_global.png
# 🎉 FINAL TEST RESULTS:
#    Accuracy: 55.03%
#    Precision: 33.73%
#    Recall: 37.25%
#    F1-Score: 33.57%
# {'test_accuracy': 55.02533783783784,
#  'test_precision': 33.731744771988346,
#  'test_recall': 37.25167493899614,
#  'test_f1_score': 33.570469937410806,
#  'per_class_metrics': {'Bằng lăng': {'precision': 28.985507246376812,
#    'recall': 64.51612903225806,
#    'f1_score': 40.0,
#    'support': 31},
#   'Gội': {'precision': 47.82608695652174,
#    'recall': 28.205128205128204,
#    'f1_score': 35.483870967741936,
#    'support': 117},
#   'Gội trắng': {'precision': 32.82442748091603,
#    'recall': 35.53719008264463,
#    'f1_score': 34.12698412698413,
#    'support': 121},
#   'Keo Lá Tràm ( Rụng Lá)': {'precision': 58.97435897435898,
#    'recall': 95.83333333333334,
#    'f1_score': 73.01587301587301,
#    'support': 24},
#   'Keo lá tràm': {'precision': 92.25941422594143,
#    'recall': 73.01324503311258,
#    'f1_score': 81.51571164510166,
#    'support': 604},
#   'Lát Hoa': {'precision': 34.74576271186441,
#    'recall': 60.29411764705882,
#    'f1_score': 44.086021505376344,
#    'support': 204},
#   'Phượng vĩ': {'precision': 28.8135593220339,
#    'recall': 9.883720930232558,
#    'f1_score': 14.71861471861472,
#    'support': 172},
#   'Re hương': {'precision': 41.01040118870728,
#    'recall': 66.34615384615384,
#    'f1_score': 50.688705234159784,
#    'support': 416},
#   'Sấu': {'precision': 17.28395061728395,
#    'recall': 12.389380530973451,
#    'f1_score': 14.432989690721648,
#    'support': 226},
#   'Sồi Phảng': {'precision': 0.0,
#    'recall': 0.0,
#    'f1_score': 0.0,
#    'support': 12},
#   'Sữa': {'precision': 0.0, 'recall': 0.0, 'f1_score': 0.0, 'support':
patch3.png:  mismatching "local" filename (VNUF_299_Patches/─Рa/646_patch3.png),
#          continuing with "central" filename version
#   inflating: VNUF_299_Patches/Đa/646_patch3.png
# VNUF_299_Patches/Đa/646_patch4.png:  mismatching "local" filename (VNUF_299_Patches/─Рa/646_patch4.png),
#          continuing with "central" filename version
#   inflating: VNUF_299_Patches/Đa/646_patch4.png
# VNUF_299_Patches/Đa/646_patch5.png:  mismatching "local" filename (VNUF_299_Patches/─Рa/646_patch5.png),
#          continuing with "central" filename version
#   inflating: VNUF_299_Patches/Đa/646_patch5.png
# VNUF_299_Patches/Đa/646_patch6.png:  mismatching "local" filename (VNUF_299_Patches/─Рa/646_patch6.png),
#          continuing with "central" filename version
#   inflating: VNUF_299_Patches/Đa/646_patch6.png
# VNUF_299_Patches/Đa/646_patch7.png:  mismatching "local" filename (VNUF_299_Patches/─Рa/646_patch7.png),
#          continuing with "central" filename version
#   inflating: VNUF_299_Patches/Đa/646_patch7.png
# VNUF_299_Patches/Đa/646_patch8.png:  mismatching "local" filename (VNUF_299_Patches/─Рa/646_patch8.png),
#          continuing with "central" filename version
#   inflating: VNUF_299_Patches/Đa/646_patch8.png
# VNUF_299_Patches/Đa/646_patch9.png:  mismatching "local" filename (VNUF_299_Patches/─Рa/646_patch9.png),
#          continuing with "central" filename version
#   inflating: VNUF_299_Patches/Đa/646_patch9.png
# VNUF_299_Patches/Đa/7_patch1.png:  mismatching "local" filename (VNUF_299_Patches/─Рa/7_patch1.png),
#          continuing with "central" filename version
#   inflating: VNUF_299_Patches/Đa/7_patch1.png
# VNUF_299_Patches/Đa/7_patch2.png:  mismatching "local" filename (VNUF_299_Patches/─Рa/7_patch2.png),
#          continuing with "central" filename version
#   inflating: VNUF_299_Patches/Đa/7_patch2.png
# VNUF_299_Patches/Đa/7_patch3.png:  mismatching "local" filename (VNUF_299_Patches/─Рa/7_patch3.png),
#          continuing with "central" filename version
#   inflating: VNUF_299_Patches/Đa/7_patch3.png

# %%
# !rm -rf /content/VNUF_299_Patches/Sếu

# %%
TEST_DIR = "/content/VNUF_299_Patches"
# 2. Cell này dùng để Test riêng biệt
print("Running Testing Step...")

# Sử dụng model đã lưu từ lần train trước
model_path = f"Single_best_{DEFAULT_CONFIG['model_name']}.pth"
# model_path = "/content/drive/MyDrive/PlantIdentification/saved_models/Single_best_densenet201.pth"

# Chạy test
run_testing(model_path)
# Out:
# Running Testing Step...
# 🚀 Starting Testing Process using model: Single_best_densenet201.pth...
# Number of classes: 14
# Using Focal Loss (alpha=1.0, gamma=2.0)
# Adding Center Loss
# Adding CORAL Loss
# Model: densenet201
# Device: cuda
# Adding CenterLoss centers to optimizer
# Loading model from Single_best_densenet201.pth
#
# ======================================================================
# 🧪 EVALUATING ON TEST SET
# ======================================================================
# Testing: 100%|██████████| 116/116 [00:21<00:00,  5.32it/s, Loss=25.1345, Acc=71.09%]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 🎯 DETAILED TEST RESULTS
# ======================================================================
# Overall Accuracy: 71.09%
# Overall Precision (Macro): 60.39%
# Overall Recall (Macro): 49.80%
# Overall F1-Score (Macro): 49.48%
# ======================================================================
#
# 📊 PER-CLASS METRICS:
# ----------------------------------------------------------------------
# Class                Precision    Recall       F1-Score     Support
# ----------------------------------------------------------------------
# Bằng lăng            64.81      % 65.42      % 65.12      % 107
# Gội                  67.80      % 40.61      % 50.79      % 394
# Gội trắng            49.12      % 65.28      % 56.06      % 386
# Keo Lá Tràm ( Rụng Lá) 61.60      % 83.70      % 70.97      % 92
# Keo lá tràm          79.74      % 91.25      % 85.11      % 1669
# Lát Hoa              77.47      % 88.02      % 82.41      % 676
# Phượng vĩ            91.81      % 63.93      % 75.37      % 596
# Re hương             50.69      % 74.24      % 60.25      % 1184
# Sấu                  47.47      % 18.93      % 27.06      % 745
# Sồi Phảng            0.00       % 0.00       % 0.00       % 44
# Sữa                  62.50      % 10.42      % 17.86      % 48
# Thông mã vĩ          92.40      % 89.67      % 91.02      % 1288
# Vả                   0.00       % 0.00       % 0.00       % 26
# Đa                   100.00     % 5.69       % 10.77      % 123
# ----------------------------------------------------------------------
#
# 📈 CLASSIFICATION REPORT:
#                         precision    recall  f1-score   support
#
#              Bằng lăng     0.6481    0.6542    0.6512       107
#                    Gội     0.6780    0.4061    0.5079       394
#              Gội trắng     0.4912    0.6528    0.5606       386
# Keo Lá Tràm ( Rụng Lá)     0.6160    0.8370    0.7097        92
#            Keo lá tràm     0.7974    0.9125    0.8511      1669
#                Lát Hoa     0.7747    0.8802    0.8241       676
#              Phượng vĩ     0.9181    0.6393    0.7537       596
#               Re hương     0.5069    0.7424    0.6025      1184
#                    Sấu     0.4747    0.1893    0.2706       745
#              Sồi Phảng     0.0000    0.0000    0.0000        44
#                    Sữa     0.6250    0.1042    0.1786        48
#            Thông mã vĩ     0.9240    0.8967    0.9102      1288
#                     Vả     0.0000    0.0000    0.0000        26
#                     Đa     1.0000    0.0569    0.1077       123
#
#               accuracy                         0.7109      7378
#              macro avg     0.6039    0.4980    0.4948      7378
#           weighted avg     0.7158    0.7109    0.6895      7378
#
#
# 💾 Test metrics saved to test_metrics.json
# 📊 Confusion matrix saved to test_confusion_matrix.png
# 📊 Confusion matrix saved to test_confusion_matrix_global.png
# 🎉 FINAL TEST RESULTS:
#    Accuracy: 71.09%
#    Precision: 60.39%
#    Recall: 49.80%
#    F1-Score: 49.48%
# {'test_accuracy': 71.08972621306587,
#  'test_precision': 60.38717343881236,
#  'test_recall': 49.79672663451712,
#  'test_f1_score': 49.4843881091596,
#  'per_class_metrics': {'Bằng lăng': {'precision': 64.81481481481481,
#    'recall': 65.42056074766354,
#    'f1_score': 65.11627906976744,
#    'support': 107},
#   'Gội': {'precision': 67.79661016949152,
#    'recall': 40.609137055837564,
#    'f1_score': 50.79365079365079,
#    'support': 394},
#   'Gội trắng': {'precision': 49.122807017543856,
#    'recall': 65.28497409326425,
#    'f1_score': 56.0622914349277,
#    'support': 386},
#   'Keo Lá Tràm ( Rụng Lá)': {'precision': 61.6,
#    'recall': 83.69565217391305,
#    'f1_score': 70.96774193548387,
#    'support': 92},
#   'Keo lá tràm': {'precision': 79.73821989528795,
#    'recall': 91.25224685440384,
#    'f1_score': 85.10757194747136,
#    'support': 1669},
#   'Lát Hoa': {'precision': 77.47395833333334,
#    'recall': 88.01775147928994,
#    'f1_score': 82.40997229916897,
#    'support': 676},
#   'Phượng vĩ': {'precision': 91.80722891566265,
#    'recall': 63.92617449664429,
#    'f1_score': 75.37091988130564,
#    'support': 596},
#   'Re hương': {'precision': 50.69204152249135,
#    'recall': 74.23986486486487,
#    'f1_score': 60.24674434544208,
#    'support': 1184},
#   'Sấu': {'precision': 47.474747474747474,
#    'recall': 18.926174496644297,
#    'f1_score': 27.06333973128599,
#    'support': 745},
#   'Sồi Phảng': {'precision': 0.0,
#    'recall': 0.0,
#    'f1_score': 0.0,
#    'support': 44},
#   'Sữa': {'precision': 62.5,
#    'recall': 10.416666666666668,
#    'f1_score': 17.857142857142858,
#    'support': 48},
#   'Thông mã vĩ': {'precision': 92.4,
#    'recall': 89.67391304347827,
#    'f1_score': 91.01654846335697,
#    'support': 1288},
#   'Vả': {'precision': 0.0, 'recall': 0.0, 'f1_score': 0.0, 'support': 26},
#   'Đa': {'precision': 100.0,
#    'recall': 5.691056910569105,
#    'f1_score': 10.76923076923077,
#    'support': 123}}}
